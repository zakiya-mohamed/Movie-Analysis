# %% [markdown]
# ## Extraction of audio (`.mp3`) from video (`.mp4`)files
# Program that extracts audio from a video file (i.e., conversion of a `.mp4` file to a `.mp3` file

# %% [markdown]
# 1) Mount google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/02 _FYP/03 Video
# Out:
# /content/gdrive/MyDrive/02 _FYP/03 Video

# %%
ls
# Out:
# AA_2019.mp4     MIBI_2019.mp4  RPO_2018.mp4
# Logan_2017.mp4  PRU_2018.mp4   TTLK_2017.mp4

# %% [markdown]
# 2) Import `moviepy.editor`

# %%
import moviepy.editor
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %% [markdown]
# 3) Convert `.mp4` to `.mp3` for all movies

# %% [markdown]
# - **Logan (2017)**

# %%
video = moviepy.editor.VideoFileClip('Logan_2017.mp4')
audio = video.audio
audio.write_audiofile('Logan_2017.mp3')
# Out:
# [MoviePy] Writing audio in Logan_2017_Audio.mp3
# 100%|██████████| 181766/181766 [04:56<00:00, 612.15it/s]
# [MoviePy] Done.

# %% [markdown]
# - **Transformers: The Last Knight (2017)**

# %%
video = moviepy.editor.VideoFileClip('TTLK_2017.mp4')
audio = video.audio
audio.write_audiofile('TTLK_2017.mp3')
# Out:
# [MoviePy] Writing audio in TTLK_2017.mp3
# 100%|██████████| 204598/204598 [06:12<00:00, 549.70it/s]
# [MoviePy] Done.

# %% [markdown]
# - **Ready Player One (2018)**

# %%
video = moviepy.editor.VideoFileClip('RPO_2018.mp4')
audio = video.audio
audio.write_audiofile('RPO_2017.mp3')
# Out:
# [MoviePy] Writing audio in RPO_2017.mp3
# 100%|██████████| 185126/185126 [05:40<00:00, 543.68it/s]
# [MoviePy] Done.

# %% [markdown]
# - **Pacific Rim: Uprising (2018)**

# %%
video = moviepy.editor.VideoFileClip('PRU_2018.mp4')
audio = video.audio
audio.write_audiofile('PRU_2018.mp3')
# Out:
# [MoviePy] Writing audio in PRU_2018.mp3
# 100%|██████████| 146462/146462 [04:28<00:00, 545.70it/s]
# [MoviePy] Done.

# %% [markdown]
# - **Ad Astra (2019)**

# %%
video = moviepy.editor.VideoFileClip('AA_2019.mp4')
audio = video.audio
audio.write_audiofile('AA_2019.mp3')
# Out:
# [MoviePy] Writing audio in AA_2019.mp3
# 100%|██████████| 165627/165627 [04:55<00:00, 560.81it/s]
# [MoviePy] Done.

# %% [markdown]
# - **Men In Black: International (2019)**

# %%
video = moviepy.editor.VideoFileClip('MIBI_2019.mp4')
audio = video.audio
audio.write_audiofile('MIBI_2019.mp3')
# Out:
# [MoviePy] Writing audio in MIBI_2019.mp3
# 100%|██████████| 151894/151894 [04:26<00:00, 571.02it/s]
# [MoviePy] Done.
