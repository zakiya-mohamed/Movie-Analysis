# %% [markdown]
# ## Movie Word Cloud
# A word cloud is a visually prominent presentation of “keywords” that appear frequently in text data. The rendering of keywords forms a cloud-like color picture, so that you can appreciate the main text data at a glance
#
#
# ### Steps to generate a Word Cloud:
# - Subtitle (.srt) file is converted into a text (.txt) file (i.e., timestamps are removed to leave dialogues only)
# - The text data is segmented
# - The frequency of each word in the text is calculated. Word frequency calculation is equivalent to word count
# - A picture layout proportionally based on the value of the word frequency is generated
#
# Code reference: https://www.topcoder.com/thrive/articles/word-cloud-in-python

# %% [markdown]
# 1) Mount google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd /content/gdrive/MyDrive/02_FYP
# Out:
# /content/gdrive/MyDrive/02_FYP

# %%
ls
# Out:
#  01_Subtitles/  '04_Text '/          NEW_Logan_2017.txt   NEW_RPO_2018.txt
#  02_Audio/      'Colab Notebooks'/   NEW_MIBI_2019.txt    NEW_TTLK_2017.txt
#  03_Video/       NEW_AA_2019.txt     NEW_PRU_2018.txt

# %% [markdown]
# 2) Import required python modules

# %%
import numpy as np
from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS

# %% [markdown]
# 3) Load `.txt` file of movie subtitles

# %%
text = open('NEW_Logan_2017.txt', 'r').read()

# %% [markdown]
# 4) Create wordcloud and save to desktop

# %%
wc = WordCloud(background_color = 'white', width = 1920, height = 1080)
wc.generate_from_text(text)
wc.to_file('Logan (2017) Word Cloud.png')

# %% [markdown]
# 5) Replicate for remaining movies

# %% [markdown]
# - **Transformers: The Last Knight (2017)**

# %%
text = open('NEW_TTLK_2017.txt', 'r').read()

# %%
wc = WordCloud(background_color = 'white', width = 1920, height = 1080)
wc.generate_from_text(text)
wc.to_file('Transformers: The Last Knight (2017) Word Cloud.png')

# %% [markdown]
# - **Ready Player One (2018)**

# %%
text = open('NEW_RPO_2018.txt', 'r').read()

# %%
wc = WordCloud(background_color = 'white', width = 1920, height = 1080)
wc.generate_from_text(text)
wc.to_file('Ready Player One (2018) Word Cloud.png')

# %% [markdown]
# - **Pacific Rim: Uprising (2018)**

# %%
text = open('NEW_PRU_2018.txt', 'r').read()

# %%
wc = WordCloud(background_color = 'white', width = 1920, height = 1080)
wc.generate_from_text(text)
wc.to_file('Pacific Rim: Uprising (2018) Word Cloud.png')

# %% [markdown]
# - **Ad Astra (2019)**

# %%
text = open('NEW_AA_2019.txt', 'r').read()

# %%
wc = WordCloud(background_color = 'white', width = 1920, height = 1080)
wc.generate_from_text(text)
wc.to_file('Ad Astra (2019) Word Cloud.png')

# %% [markdown]
# - **Men In Black: International (2019)**

# %%
text = open('NEW_MIBI_2019.txt', 'r').read()

# %%
wc = WordCloud(background_color = 'white', width = 1920, height = 1080)
wc.generate_from_text(text)
wc.to_file('Men In Black: International (2019) Word Cloud.png')
